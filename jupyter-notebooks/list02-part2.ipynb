# %% [markdown]
# # Листок 02. Визуализация

# %% [markdown]
# ## Упражнение 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# подключим датасет Labour
df = pd.read_csv('Labour.csv')
df.shape
# Out:
# (569, 4)

# %% [markdown]
# 2. нарисуйте гистограммы для log-переменных output, capital, labour, wage

# %%
sns.histplot(x=np.log(df['output']))
plt.xlabel('log(output)')
# Out:
# Text(0.5, 0, 'log(output)')

# %% [markdown]
# 4. нарисуйте диаграммы рассеяния log(output) vs log других переменных

# %%
# названия столбцов (признаков)
df.columns
# Out:
# Index(['capital', 'labour', 'output', 'wage'], dtype='object')

# %%
sns.scatterplot(x=np.log(df['capital']), y=np.log(df['output']))
plt.xlabel('log(capital)')
plt.ylabel('log(output)')
# Out:
# Text(0, 0.5, 'log(output)')
